# %% [markdown]
# # A short introduction to containerized software
#
# After spending time using nf-core pipelines to answer bioinformatic questions, we will focus on the processes that lie behind these pipelines now.
#
# Today, we will focus on containerization, namely via Docker.

# %% [markdown]
# 1. Check if Docker is installed.

# %%
# !docker info
# Out:
# Client:
#  Version:    28.4.0
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.9.11
#     Path:     /usr/local/lib/docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.28.0-desktop.1
#     Path:     /usr/local/lib/docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.4.29
#     Path:     /usr/local/lib/docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.39.4-desktop.1
#     Path:     /usr/local/lib/docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.42
#     Path:     /usr/local/lib/docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.2.0
#     Path:     /usr/local/lib/docker/cli-plugins/docker-desktop
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.31
#     Path:     /usr/local/lib/docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /usr/local/lib/docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  v0.21.0
#     Path:     /home/johannae/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.41
#     Path:     /usr/local/lib/docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /usr/local/lib/docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.18.3
#     Path:     /usr/local/lib/docker/cli-plugins/docker-scout
#
# Server:
#  Containers: 1
#   Running: 1
#   Paused: 0
#   Stopped: 0
#  Images: 13
#  Server Version: 28.4.0
#  Storage Driver: overlayfs
#   driver-type: io.containerd.snapshotter.v1
#  Logging Driver: json-file
#  Cgroup Driver: cgroupfs
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local splunk syslog
#  CDI spec directories:
#   /etc/cdi
#   /var/run/cdi
#  Discovered Devices:
#   cdi: docker.com/gpu=webgpu
#  Swarm: inactive
#  Runtimes: io.containerd.runc.v2 nvidia runc
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 05044ec0a9a75232cad458027ca83437aae3f4da
#  runc version: v1.2.5-0-g59923ef
#  init version: de40ad0
#  Security Options:
#   seccomp
#    Profile: builtin
#   cgroupns
#  Kernel Version: 6.6.87.2-microsoft-standard-WSL2
#  Operating System: Docker Desktop
#  OSType: linux
#  Architecture: x86_64
#  CPUs: 8
#  Total Memory: 7.696GiB
#  Name: docker-desktop
#  ID: 808b30f7-71d2-4f7f-b2bf-2305953a6cd4
#  Docker Root Dir: /var/lib/docker
#  Debug Mode: false
#  HTTP Proxy: http.docker.internal:3128
#  HTTPS Proxy: http.docker.internal:3128
#  No Proxy: hubproxy.docker.internal
#  Labels:
#   com.docker.desktop.address=unix:///var/run/docker-cli.sock
#  Experimental: false
#  Insecure Registries:
#   hubproxy.docker.internal:5555
#   ::1/128
#   127.0.0.0/8
#  Live Restore Enabled: false

# %% [markdown]
# ### What is a docker container
#
# A Docker container is a standardized, encapsulated environment that runs applications.
#
# https://en.wikipedia.org/wiki/Docker_(software)

# %% [markdown]
# ### Why do we use containers?
#
# Containers isolate software from its environment and ensure that it works uniformly despite differences for instance between development and staging.
#
# https://www.docker.com/resources/what-container/

# %% [markdown]
# ### What is a docker image?
#
# A Docker image is a read-only template (kind of blue-print) used to build containers. Images are used to store and ship applications.[1] Container images become containers at runtime and in the case of Docker containers – images become containers when they run on Docker Engine.[2]
#
# 1 https://en.wikipedia.org/wiki/Docker_(software)
# 2 https://www.docker.com/resources/what-container/

# %% [markdown]
# ### Let's run our first docker image:

# %% [markdown]
# ### Login to docker

# %%
# This you need to do on the command line directly

# %% [markdown]
# ### Run your first docker container

# %%
# !docker run hello-world
# Out:
# Unable to find image 'hello-world:latest' locally
# latest: Pulling from library/hello-world
#
# Digest: sha256:54e66cc1dd1fcb1c3c58bd8017914dbed8701e2d8c74d9262e26bd9cc1642d31
# Status: Downloaded newer image for hello-world:latest
#
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %%
# !docker --help
# Out:
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#   bake        Build from a file
#   pull        Download an image from a registry
#   push        Upload an image to a registry
#   images      List images
#   login       Authenticate to a registry
#   logout      Log out from a registry
#   search      Search Docker Hub for images
#   version     Show the Docker version information
#   info        Display system-wide information
#
# Management Commands:
#   ai*         Docker AI Agent - Ask Gordon
#   builder     Manage builds
#   buildx*     Docker Buildx
#   cloud*      Docker Cloud
#   compose*    Docker Compose
#   container   Manage containers
#   context     Manage contexts
#   debug*      Get a shell into any image or container
#   desktop*    Docker Desktop commands
#   extension*  Manages Docker extensions
#   image       Manage images
#   init*       Creates Docker-related starter files for your project
#   manifest    Manage Docker image manifests and manifest lists
#   mcp*        Docker MCP Plugin
#   model*      Docker Model Runner
#   network     Manage networks
#   plugin      Manage plugins
#   sbom*       View the packaged-based Software Bill Of Materials (SBOM) for an image
#   scout*      Docker Scout
#   system      Manage Docker
#   trust       Manage trust on Docker images
#   volume      Manage volumes
#
# Swarm Commands:
#   swarm       Manage Swarm
#
# Commands:
#   attach      Attach local standard input, output, and error streams to a running container
#   commit      Create a new image from a container's changes
#   cp          Copy files/folders between a container and the local filesystem
#   create      Create a new container
#   diff        Inspect changes to files or directories on a container's filesystem
#   events      Get real time events from the server
#   export      Export a container's filesystem as a tar archive
#   history     Show the history of an image
#   import      Import the contents from a tarball to create a filesystem image
#   inspect     Return low-level information on Docker objects
#   kill        Kill one or more running containers
#   load        Load an image from a tar archive or STDIN
#   logs        Fetch the logs of a container
#   pause       Pause all processes within one or more containers
#   port        List port mappings or a specific mapping for the container
#   rename      Rename a container
#   restart     Restart one or more containers
#   rm          Remove one or more containers
#   rmi         Remove one or more images
#   save        Save one or more images to a tar archive (streamed to STDOUT by default)
#   start       Start one or more stopped containers
#   stats       Display a live stream of container(s) resource usage statistics
#   stop        Stop one or more running containers
#   tag         Create a tag TARGET_IMAGE that refers to SOURCE_IMAGE
#   top         Display the running processes of a container
#   unpause     Unpause all processes within one or more containers
#   update      Update configuration of one or more containers
#   wait        Block until one or more containers stop, then print their exit codes
#
# Global Options:
#       --config string      Location of client config files (default
#                            "/home/johannae/.docker")
#   -c, --context string     Name of the context to use to connect to the
#                            daemon (overrides DOCKER_HOST env var and
#                            default context set with "docker context use")
#   -D, --debug              Enable debug mode
#   -H, --host string        Daemon socket to connect to
#   -l, --log-level string   Set the logging level ("debug", "info",
#                            "warn", "error", "fatal") (default "info")
#       --tls                Use TLS; implied by --tlsverify
#       --tlscacert string   Trust certs signed only by this CA (default
#                            "/home/johannae/.docker/ca.pem")
#       --tlscert string     Path to TLS certificate file (default
#                            "/home/johannae/.docker/cert.pem")
#       --tlskey string      Path to TLS key file (default
#                            "/home/johannae/.docker/key.pem")
#       --tlsverify          Use TLS and verify the remote
#   -v, --version            Print version information and quit
#
# Run 'docker COMMAND --help' for more information on a command.
#
# For more help on how to use Docker, head to https://docs.docker.com/go/guides/

# %% [markdown]
# ### Find the container ID

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE                                                              COMMAND                  CREATED          STATUS                           PORTS     NAMES
# c41d8bc80ef7   cowsay                                                             "cowsay 'hello world'"   52 minutes ago   Exited (0) 52 minutes ago                  inspiring_mayer
# c7874cfac07a   cowsay                                                             "hello world"            53 minutes ago   Created                                    awesome_bassi
# 084bfff4282e   cowsay                                                             "bash"                   53 minutes ago   Exited (0) 53 minutes ago                  wizardly_carson
# 4ef9bcac4d86   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (130) About an hour ago             festive_morse
# 1fce1701c548   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (0) 2 hours ago                     pedantic_cohen
# 81f5c4150a2f   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (0) 2 hours ago                     inspiring_beaver
# 8ce06859f33a   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     jovial_bell
# 33925b1c4b45   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     focused_mccarthy
# 21023dcb43fd   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     jovial_babbage
# c105f8724c38   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     mystifying_stonebraker
# 7cbc3a6be314   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     confident_vaughan
# 8fd3c4959fd5   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     gallant_fermat
# 367848aeb3c6   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     romantic_sinoussi
# 66ffb3ba8729   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     inspiring_shannon
# e4fc8b78ff51   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     eloquent_williams
# 651ceccd6e9f   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     jolly_babbage
# 6d005b290ba6   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (0) 2 hours ago                     jovial_murdock
# c61e70bb3452   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     busy_mestorf
# 319328714a5d   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     determined_goldberg
# 4fc72a467e3e   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (0) 2 hours ago                     sweet_allen
# 8a0177b3126f   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (0) 2 hours ago                     cool_herschel
# 6f68c89a2c49   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (0) 2 hours ago                     heuristic_hermann

# %% [markdown]
# ### Delete the container again, give prove its deleted

# %%
# !docker rm 6a580cb9beb2
# Out:
# Error response from daemon: No such container: 6a580cb9beb2

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE                                                              COMMAND                  CREATED          STATUS                           PORTS     NAMES
# c41d8bc80ef7   cowsay                                                             "cowsay 'hello world'"   53 minutes ago   Exited (0) 53 minutes ago                  inspiring_mayer
# c7874cfac07a   cowsay                                                             "hello world"            53 minutes ago   Created                                    awesome_bassi
# 084bfff4282e   cowsay                                                             "bash"                   53 minutes ago   Exited (0) 53 minutes ago                  wizardly_carson
# 4ef9bcac4d86   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (130) About an hour ago             festive_morse
# 1fce1701c548   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (0) 2 hours ago                     pedantic_cohen
# 81f5c4150a2f   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (0) 2 hours ago                     inspiring_beaver
# 8ce06859f33a   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     jovial_bell
# 33925b1c4b45   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     focused_mccarthy
# 21023dcb43fd   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     jovial_babbage
# c105f8724c38   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     mystifying_stonebraker
# 7cbc3a6be314   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     confident_vaughan
# 8fd3c4959fd5   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     gallant_fermat
# 367848aeb3c6   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     romantic_sinoussi
# 66ffb3ba8729   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     inspiring_shannon
# e4fc8b78ff51   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     eloquent_williams
# 651ceccd6e9f   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     jolly_babbage
# 6d005b290ba6   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (0) 2 hours ago                     jovial_murdock
# c61e70bb3452   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     busy_mestorf
# 319328714a5d   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (2) 2 hours ago                     determined_goldberg
# 4fc72a467e3e   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (0) 2 hours ago                     sweet_allen
# 8a0177b3126f   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (0) 2 hours ago                     cool_herschel
# 6f68c89a2c49   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   2 hours ago      Exited (0) 2 hours ago                     heuristic_hermann

# %% [markdown]
# ### FASTQC is a very useful tool as you've learned last week. Let's try and run it from command line
#
# Link to the software: https://www.bioinformatics.babraham.ac.uk/projects/fastqc/

# %% [markdown]
# Please describe the steps you took to download and run the software for the example fastq file from last week below:

# %% [markdown]
# 1. I followed the link and clicked "download now"
# 2. I tried to read the instructions but they were more confusing
# 3. Downloaded the Zip file for linux and windows.
# 4. I opend the software with "run_fastqc"
# 5. And then I chose the first fast_qc file from yesterday: SRX19144486_SRR23195516_1.fastq
#
# I have kind of the same results like yesterday.

# %% [markdown]
# ### Very well, now let's try to make use of its docker container
#
# 1. create a container holding fastqc using seqera containers (https://seqera.io/containers/)
# 2. use the container to generate a fastqc html of the example fastq file

# %%
# pull the container
# !docker pull community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29
# Out:
# 0.12.1--af7a5314d5015c29: Pulling from library/fastqc
# Digest: sha256:b7f6caf359264cf86da901b0aa5f66735a6506fcfbf103c66db6987253ad44c1
# Status: Image is up to date for community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29
# community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29

# %%
# !docker images
# Out:
# REPOSITORY                                                 TAG                        IMAGE ID       CREATED             SIZE
# cowsay                                                     latest                     da4660cce0ba   About an hour ago   191MB
# hello-world                                                latest                     54e66cc1dd1f   7 weeks ago         20.3kB
# community.wave.seqera.io/library/fastqc                    0.12.1--af7a5314d5015c29   b7f6caf35926   11 months ago       1.37GB
# quay.io/biocontainers/samtools                             1.21--h50ea8bc_0           783c6646029a   12 months ago       108MB
# quay.io/biocontainers/fq                                   0.12.0--h9ee0642_0         74b59572f1d0   14 months ago       20MB
# quay.io/biocontainers/r-shinyngs                           1.8.8--r43hdfd78af_0       e0de72408557   17 months ago       1.99GB
# quay.io/biocontainers/atlas-gene-annotation-manipulation   1.1.1--hdfd78af_0          099d0e113ec8   18 months ago       1.82GB
# quay.io/nf-core/ubuntu                                     20.04                      59e9d08d8dc1   2 years ago         110MB
# quay.io/biocontainers/pandas                               1.5.2                      cbb54fcf8730   2 years ago         493MB
# quay.io/biocontainers/gsea                                 4.3.2--hdfd78af_0          0010041fff53   2 years ago         849MB
# quay.io/biocontainers/r-base                               4.2.1                      6721ee8bfba2   2 years ago         1.17GB
# quay.io/biocontainers/p7zip                                16.02                      731aaeef376a   3 years ago         47.7MB
# quay.io/biocontainers/python                               3.9--1                     d97d2b329b4e   4 years ago         275MB
# quay.io/biocontainers/gawk                                 5.1.0                      9d300f3d0a35   5 years ago         53.4MB
# quay.io/biocontainers/bioconductor-deseq2                  1.34.0--r41hc247a5b_3      c06884d353ef   55 years ago        452MB
# quay.io/biocontainers/wget                                 1.20.1                     7e5ba9e87a25   55 years ago        26.9MB

# %%
# !docker run community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29

# %%
# run the container and save the results to a new "fastqc_results" directory
# !docker run community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29 fastqc \
    -v /mnt/c/Users/Johanna/Documents/Studium_Tübingen/2_Semester/computational-workflows-2025/notebooks/day_02/test/fastq/SRX19144486_SRR23195516_1.fastq \
    fastqc -o /mnt/c/Users/Johanna/Documents/Studium_Tübingen/2_Semester/computational-workflows-2025/notebooks/day_02/test/fastq/SRX19144486_SRR23195516_1.fastq
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# Specified output directory '/mnt/c/Users/Johanna/Documents/Studium_Tübingen/2_Semester/computational-workflows-2025/notebooks/day_02/test/fastq/SRX19144486_SRR23195516_1.fastq' does not exist

# %%
# !docker run \
    -v "/mnt/c/Users/Johanna/Documents/Studium_Tübingen/2_Semester/computational-workflows-2025/notebooks/day_02/test/fastq:/data" \
    -v "/mnt/c/Users/Johanna/Documents/Studium_Tübingen/2_Semester/computational-workflows-2025/notebooks/day_02/test/fastqc_results:/results" \
    community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29 \
    fastqc /data/SRX19144486_SRR23195516_1.fastq.gz -o /results
# Out:
# application/gzip
# Started analysis of SRX19144486_SRR23195516_1.fastq.gz
# Approx 5% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 10% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 15% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 20% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 25% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 30% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 35% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 40% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 45% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 50% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 55% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 60% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 65% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 70% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 75% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 80% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 85% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 90% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 95% complete for SRX19144486_SRR23195516_1.fastq.gz
# Analysis complete for SRX19144486_SRR23195516_1.fastq.gz

# %% [markdown]
# ### Now that you know how to use a docker container, which approach was easier and which approach will be easier in the future?
#
# I am really sorry to say, it was way easier to downloas the fastqc and then run it. It took me round about 50 minutes to pull the image, and run the container with the right commands and input/output file names... Also the runtime of the container is longer than in the application.

# %% [markdown]
# ### What would you say, which approach is more reproducible?
#
# I haven't test reproducibility, but I think the container would be more stable and reproducible. And now that I figure out how to run it, I might be faster next time.

# %% [markdown]
# ### Compare the file to last weeks fastqc results, are they identical?
# ### Is the fastqc version identical?

# %% [markdown]
# ## Dockerfiles
#
# We now used Docker containers and images directly to boost our research.
#
# Let's create our own toy Dockerfile including the "cowsay" tool (https://en.wikipedia.org/wiki/Cowsay)
#
# Hints:
# 1. Docker is Linux, so you need to know the apt-get command to install "cowsay"

# %%
# open the file "my_dockerfile" in a text editor

# %% [markdown]
# ### Explain the RUN and ENV lines you added to the file

# %% [markdown]
# RUN: To run the commans
# ENV:

# %%
# !pwd
# Out:
# /mnt/c/Users/Johanna/Documents/Studium_Tübingen/2_Semester/computational-workflows-2025/notebooks/day_03_part2

# %%
# build the docker image
# !docker build -t cowsay -f "/mnt/c/Users/Johanna/Documents/Studium_Tübingen/2_Semester/computational-workflows-2025/notebooks/day_03_part2/my_dockerfile" .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.1s (0/1)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.1s
#  => => transferring dockerfile: 33B                                        0.0s
# [+] Building 0.4s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.2s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
# [+] Building 0.7s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
# [+] Building 0.8s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
# [+] Building 1.0s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.8s
# [+] Building 1.1s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
# [+] Building 1.3s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
# [+] Building 1.3s (1/3)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.5s (2/3)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.6s (2/3)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.4s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.8s (2/3)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.9s (2/3)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 2.1s (2/3)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 2.2s (2/3)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 2.4s (2/3)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 2.5s (2/3)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 2.6s (3/3)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 2.7s (4/4)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
# [+] Building 2.8s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
# [+] Building 3.0s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
# [+] Building 3.1s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.2s
# [+] Building 3.2s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.3s
# [+] Building 3.4s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.5s
# [+] Building 3.5s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 1.05MB / 30.26MB  0.6s
# [+] Building 3.7s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 1.05MB / 30.26MB  0.8s
# [+] Building 3.7s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 2.10MB / 30.26MB  0.8s
# [+] Building 3.8s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 3.15MB / 30.26MB  0.9s
# [+] Building 4.0s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 3.15MB / 30.26MB  1.1s
# [+] Building 4.0s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 4.19MB / 30.26MB  1.1s
# [+] Building 4.1s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 4.19MB / 30.26MB  1.2s
# [+] Building 4.1s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 5.24MB / 30.26MB  1.2s
# [+] Building 4.3s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 6.29MB / 30.26MB  1.4s
# [+] Building 4.4s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 7.34MB / 30.26MB  1.5s
# [+] Building 4.6s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 7.34MB / 30.26MB  1.7s
# [+] Building 4.6s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 8.39MB / 30.26MB  1.7s
# [+] Building 4.7s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 9.44MB / 30.26MB  1.8s
# [+] Building 4.9s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 11.53MB / 30.26MB  2.0s
# [+] Building 5.0s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 12.58MB / 30.26MB  2.1s
# [+] Building 5.2s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 12.58MB / 30.26MB  2.3s
# [+] Building 5.2s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 13.63MB / 30.26MB  2.3s
# [+] Building 5.3s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 14.68MB / 30.26MB  2.4s
# [+] Building 5.5s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 14.68MB / 30.26MB  2.6s
# [+] Building 5.5s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 15.73MB / 30.26MB  2.6s
# [+] Building 5.6s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 16.78MB / 30.26MB  2.7s
# [+] Building 5.8s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 17.83MB / 30.26MB  2.9s
# [+] Building 5.9s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 18.87MB / 30.26MB  3.0s
# [+] Building 6.1s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 20.97MB / 30.26MB  3.2s
# [+] Building 6.2s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 20.97MB / 30.26MB  3.3s
# [+] Building 6.2s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 22.02MB / 30.26MB  3.3s
# [+] Building 6.4s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 23.07MB / 30.26MB  3.5s
# [+] Building 6.5s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 24.12MB / 30.26MB  3.6s
# [+] Building 6.7s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 24.12MB / 30.26MB  3.8s
# [+] Building 6.7s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 25.17MB / 30.26MB  3.8s
# [+] Building 6.8s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 25.17MB / 30.26MB  3.9s
# [+] Building 7.0s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 26.21MB / 30.26MB  4.1s
# [+] Building 7.1s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 26.21MB / 30.26MB  4.2s
# [+] Building 7.1s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 27.26MB / 30.26MB  4.2s
# [+] Building 7.3s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 27.26MB / 30.26MB  4.4s
# [+] Building 7.4s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 28.31MB / 30.26MB  4.5s
# [+] Building 7.6s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 28.31MB / 30.26MB  4.7s
# [+] Building 7.6s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 29.36MB / 30.26MB  4.7s
# [+] Building 7.7s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 29.36MB / 30.26MB  4.8s
# [+] Building 7.7s (5/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 29.36MB / 30.26MB  4.8s
# [+] Building 7.9s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 29.36MB / 30.26MB  5.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.2s
# [+] Building 8.1s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 29.36MB / 30.26MB  5.2s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.3s
# [+] Building 8.2s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 29.36MB / 30.26MB  5.3s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.5s
# [+] Building 8.4s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 29.36MB / 30.26MB  5.5s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.6s
# [+] Building 8.5s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 29.36MB / 30.26MB  5.6s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  0.8s
# [+] Building 8.7s (4/6)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.9s
# ...
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  8.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 29.36MB / 30.26MB  32.6s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  3.4s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recomme  17.3s
#  => exporting to image                                                     7.1s
#  => => exporting layers                                                    5.1s
#  => => exporting manifest sha256:8d2f6453377ce98d0e8d73206c2d7f1557700607  0.0s
#  => => exporting config sha256:9530f7e3904f7bd669d9a82bda786469f15acef2bd  0.0s
#  => => exporting attestation manifest sha256:669f7612b1c91c6f1f6bb5e9cc82  0.1s
#  => => exporting manifest list sha256:da4660cce0bae4deff76768e93a6c3dc80e  0.0s
#  => => naming to docker.io/library/cowsay:latest                           0.0s
#  => => unpacking to docker.io/library/cowsay:latest                        1.7s
# [+] Building 35.7s (6/7)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  8.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 29.36MB / 30.26MB  32.7s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  3.4s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recomme  17.3s
#  => exporting to image                                                     7.2s
#  => => exporting layers                                                    5.1s
#  => => exporting manifest sha256:8d2f6453377ce98d0e8d73206c2d7f1557700607  0.0s
#  => => exporting config sha256:9530f7e3904f7bd669d9a82bda786469f15acef2bd  0.0s
#  => => exporting attestation manifest sha256:669f7612b1c91c6f1f6bb5e9cc82  0.1s
#  => => exporting manifest list sha256:da4660cce0bae4deff76768e93a6c3dc80e  0.0s
#  => => naming to docker.io/library/cowsay:latest                           0.0s
#  => => unpacking to docker.io/library/cowsay:latest                        1.8s
# [+] Building 35.8s (6/7)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  8.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 29.36MB / 30.26MB  32.9s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  3.4s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recomme  17.3s
#  => exporting to image                                                     7.4s
#  => => exporting layers                                                    5.1s
#  => => exporting manifest sha256:8d2f6453377ce98d0e8d73206c2d7f1557700607  0.0s
#  => => exporting config sha256:9530f7e3904f7bd669d9a82bda786469f15acef2bd  0.0s
#  => => exporting attestation manifest sha256:669f7612b1c91c6f1f6bb5e9cc82  0.1s
#  => => exporting manifest list sha256:da4660cce0bae4deff76768e93a6c3dc80e  0.0s
#  => => naming to docker.io/library/cowsay:latest                           0.0s
#  => => unpacking to docker.io/library/cowsay:latest                        2.0s
# [+] Building 36.0s (6/7)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  8.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 29.36MB / 30.26MB  33.0s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  3.4s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recomme  17.3s
#  => exporting to image                                                     7.5s
#  => => exporting layers                                                    5.1s
#  => => exporting manifest sha256:8d2f6453377ce98d0e8d73206c2d7f1557700607  0.0s
#  => => exporting config sha256:9530f7e3904f7bd669d9a82bda786469f15acef2bd  0.0s
#  => => exporting attestation manifest sha256:669f7612b1c91c6f1f6bb5e9cc82  0.1s
#  => => exporting manifest list sha256:da4660cce0bae4deff76768e93a6c3dc80e  0.0s
#  => => naming to docker.io/library/cowsay:latest                           0.0s
#  => => unpacking to docker.io/library/cowsay:latest                        2.1s
# [+] Building 36.0s (6/7)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  8.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 29.36MB / 30.26MB  33.1s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  3.4s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recomme  17.3s
#  => exporting to image                                                     7.6s
#  => => exporting layers                                                    5.1s
#  => => exporting manifest sha256:8d2f6453377ce98d0e8d73206c2d7f1557700607  0.0s
#  => => exporting config sha256:9530f7e3904f7bd669d9a82bda786469f15acef2bd  0.0s
#  => => exporting attestation manifest sha256:669f7612b1c91c6f1f6bb5e9cc82  0.1s
#  => => exporting manifest list sha256:da4660cce0bae4deff76768e93a6c3dc80e  0.0s
#  => => naming to docker.io/library/cowsay:latest                           0.0s
#  => => unpacking to docker.io/library/cowsay:latest                        2.1s
# [+] Building 36.1s (7/7)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  8.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 29.36MB / 30.26MB  33.2s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  3.4s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recomme  17.3s
#  => exporting to image                                                     7.7s
#  => => exporting layers                                                    5.1s
#  => => exporting manifest sha256:8d2f6453377ce98d0e8d73206c2d7f1557700607  0.0s
#  => => exporting config sha256:9530f7e3904f7bd669d9a82bda786469f15acef2bd  0.0s
#  => => exporting attestation manifest sha256:669f7612b1c91c6f1f6bb5e9cc82  0.1s
#  => => exporting manifest list sha256:da4660cce0bae4deff76768e93a6c3dc80e  0.0s
#  => => naming to docker.io/library/cowsay:latest                           0.0s
#  => => unpacking to docker.io/library/cowsay:latest                        2.1s
# [+] Building 36.3s (7/7)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  8.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 29.36MB / 30.26MB  33.4s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  3.4s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recomme  17.3s
#  => exporting to image                                                     7.7s
#  => => exporting layers                                                    5.1s
#  => => exporting manifest sha256:8d2f6453377ce98d0e8d73206c2d7f1557700607  0.0s
#  => => exporting config sha256:9530f7e3904f7bd669d9a82bda786469f15acef2bd  0.0s
#  => => exporting attestation manifest sha256:669f7612b1c91c6f1f6bb5e9cc82  0.1s
#  => => exporting manifest list sha256:da4660cce0bae4deff76768e93a6c3dc80e  0.0s
#  => => naming to docker.io/library/cowsay:latest                           0.0s
#  => => unpacking to docker.io/library/cowsay:latest                        2.1s
# [+] Building 36.4s (7/7)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  8.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 29.36MB / 30.26MB  33.5s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  3.4s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recomme  17.3s
#  => exporting to image                                                     7.7s
#  => => exporting layers                                                    5.1s
#  => => exporting manifest sha256:8d2f6453377ce98d0e8d73206c2d7f1557700607  0.0s
#  => => exporting config sha256:9530f7e3904f7bd669d9a82bda786469f15acef2bd  0.0s
#  => => exporting attestation manifest sha256:669f7612b1c91c6f1f6bb5e9cc82  0.1s
#  => => exporting manifest list sha256:da4660cce0bae4deff76768e93a6c3dc80e  0.0s
#  => => naming to docker.io/library/cowsay:latest                           0.0s
#  => => unpacking to docker.io/library/cowsay:latest                        2.1s
# [+] Building 36.6s (7/7)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  8.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 29.36MB / 30.26MB  33.7s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  3.4s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recomme  17.3s
#  => exporting to image                                                     7.7s
#  => => exporting layers                                                    5.1s
#  => => exporting manifest sha256:8d2f6453377ce98d0e8d73206c2d7f1557700607  0.0s
#  => => exporting config sha256:9530f7e3904f7bd669d9a82bda786469f15acef2bd  0.0s
#  => => exporting attestation manifest sha256:669f7612b1c91c6f1f6bb5e9cc82  0.1s
#  => => exporting manifest list sha256:da4660cce0bae4deff76768e93a6c3dc80e  0.0s
#  => => naming to docker.io/library/cowsay:latest                           0.0s
#  => => unpacking to docker.io/library/cowsay:latest                        2.1s
# [+] Building 36.6s (7/7) FINISHED                                docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 864B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  8.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 29.36MB / 30.26MB  33.7s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  3.4s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recomme  17.3s
#  => exporting to image                                                     7.7s
#  => => exporting layers                                                    5.1s
#  => => exporting manifest sha256:8d2f6453377ce98d0e8d73206c2d7f1557700607  0.0s
#  => => exporting config sha256:9530f7e3904f7bd669d9a82bda786469f15acef2bd  0.0s
#  => => exporting attestation manifest sha256:669f7612b1c91c6f1f6bb5e9cc82  0.1s
#  => => exporting manifest list sha256:da4660cce0bae4deff76768e93a6c3dc80e  0.0s
#  => => naming to docker.io/library/cowsay:latest                           0.0s
#  => => unpacking to docker.io/library/cowsay:latest                        2.1s
#
#  2 warnings found (use docker --debug to expand):
#  - LegacyKeyValueFormat: "LABEL key=value" should be used instead of legacy "LABEL key value" format (line 5)
#  - LegacyKeyValueFormat: "LABEL key=value" should be used instead of legacy "LABEL key value" format (line 6)

# %%
# make sure that the image has been built
# !docker images
# Out:
# REPOSITORY                                                 TAG                        IMAGE ID       CREATED         SIZE
# cowsay                                                     latest                     da4660cce0ba   5 minutes ago   191MB
# hello-world                                                latest                     54e66cc1dd1f   7 weeks ago     20.3kB
# community.wave.seqera.io/library/fastqc                    0.12.1--af7a5314d5015c29   b7f6caf35926   11 months ago   1.37GB
# quay.io/biocontainers/samtools                             1.21--h50ea8bc_0           783c6646029a   12 months ago   108MB
# quay.io/biocontainers/fq                                   0.12.0--h9ee0642_0         74b59572f1d0   14 months ago   20MB
# quay.io/biocontainers/r-shinyngs                           1.8.8--r43hdfd78af_0       e0de72408557   17 months ago   1.99GB
# quay.io/biocontainers/atlas-gene-annotation-manipulation   1.1.1--hdfd78af_0          099d0e113ec8   18 months ago   1.82GB
# quay.io/nf-core/ubuntu                                     20.04                      59e9d08d8dc1   2 years ago     110MB
# quay.io/biocontainers/pandas                               1.5.2                      cbb54fcf8730   2 years ago     493MB
# quay.io/biocontainers/gsea                                 4.3.2--hdfd78af_0          0010041fff53   2 years ago     849MB
# quay.io/biocontainers/r-base                               4.2.1                      6721ee8bfba2   2 years ago     1.17GB
# quay.io/biocontainers/p7zip                                16.02                      731aaeef376a   3 years ago     47.7MB
# quay.io/biocontainers/python                               3.9--1                     d97d2b329b4e   4 years ago     275MB
# quay.io/biocontainers/gawk                                 5.1.0                      9d300f3d0a35   5 years ago     53.4MB
# quay.io/biocontainers/bioconductor-deseq2                  1.34.0--r41hc247a5b_3      c06884d353ef   55 years ago    452MB
# quay.io/biocontainers/wget                                 1.20.1                     7e5ba9e87a25   55 years ago    26.9MB

# %%
# run the docker file 
# !docker run cowsay cowsay "hello world"
# Out:
#  _____________
# < hello world >
#  -------------
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||

# %% [markdown]
# ## Let's do some bioinformatics with the docker file and create a new docker file that holds the salmon tool used in rnaseq
#
# To do so, use "curl" in your new dockerfile to get salmon from https://github.com/COMBINE-lab/salmon/releases/download/v1.5.2/salmon-1.5.2_linux_x86_64.tar.gz

# %%
# use the file "salmon_docker" in this directory to build a new docker image

# %%
# build the image
# !docker build -t salmon -f salmon_docker .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.2s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
# [+] Building 0.5s (2/2)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
# [+] Building 0.6s (3/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
# [+] Building 0.8s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   0.2s
# [+] Building 1.0s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   0.3s
# [+] Building 1.0s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   0.4s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [75.1 kB]
# [+] Building 1.2s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   0.6s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 1.4s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   0.7s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 1.5s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   0.9s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 1.7s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   1.0s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 1.8s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   1.2s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.0s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   1.3s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.1s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   1.5s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.3s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   1.6s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.4s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   1.8s
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
# [+] Building 2.6s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   2.0s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 2.8s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   2.1s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 2.9s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   2.3s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 3.1s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   2.4s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 3.2s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   2.6s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 3.4s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   2.7s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
# [+] Building 3.4s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   2.7s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 2s (3573 kB/s)
#  => => # Reading package lists...
# [+] Building 3.5s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   2.9s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 2s (3573 kB/s)
#  => => # Reading package lists...
# [+] Building 3.7s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   3.0s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 2s (3573 kB/s)
#  => => # Reading package lists...
# [+] Building 3.8s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   3.2s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 2s (3573 kB/s)
#  => => # Reading package lists...
# [+] Building 3.9s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   3.3s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 2s (3573 kB/s)
#  => => # Reading package lists...
# [+] Building 4.1s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   3.5s
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 2s (3573 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 4.3s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   3.6s
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 2s (3573 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 4.4s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   3.8s
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 2s (3573 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 4.5s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   3.8s
#  => => # 64 Packages [411 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 2s (3573 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 4.6s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   4.0s
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 2s (3573 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
#  => => # Building dependency tree...
#  => => # Reading state information...
# [+] Building 4.8s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   4.1s
#  => => # s [18.8 kB]
#  => => # Fetched 8642 kB in 2s (3573 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
#  => => # Building dependency tree...
#  => => # Reading state information...
# [+] Building 4.8s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   4.2s
#  => => # Reading package lists...
#  => => # Building dependency tree...
#  => => # Reading state information...
#  => => # tar is already the newest version (1.34+dfsg-1+deb11u1).
#  => => # tar set to manually installed.
#  => => # The following additional packages will be installed:
# [+] Building 4.9s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   4.3s
#  => => #   libsasl2-modules-ldap libsasl2-modules-otp libsasl2-modules-sql
#  => => # The following NEW packages will be installed:
#  => => #   ca-certificates curl libbrotli1 libcurl4 libldap-2.4-2 libldap-commo
#  => => # n
#  => => #   libnghttp2-14 libpsl5 librtmp1 libsasl2-2 libsasl2-modules
#  => => #   libsasl2-modules-db libssh2-1 openssl publicsuffix
# [+] Building 5.1s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   4.5s
#  => => #   libsasl2-modules-db libssh2-1 openssl publicsuffix
#  => => # 0 upgraded, 15 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 3000 kB of archives.
#  => => # After this operation, 6268 kB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 openssl amd64 1.1.1w-0+deb11u3 [859 kB]
# [+] Building 5.3s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   4.6s
#  => => # Need to get 3000 kB of archives.
#  => => # After this operation, 6268 kB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 openssl amd64 1.1.1w-0+deb11u3 [859 kB]
#  => => # Get:2 http://deb.debian.org/debian bullseye/main amd64 ca-certificates
#  => => #  all 20210119 [158 kB]
# [+] Building 5.4s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   4.7s
#  => => # Get:5 http://deb.debian.org/debian bullseye/main amd64 libsasl2-2 amd6
#  => => # 4 2.1.27+dfsg-2.1+deb11u1 [106 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye/main amd64 libldap-2.4-2 a
#  => => # md64 2.4.57+dfsg-3+deb11u1 [232 kB]
#  => => # Get:7 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 libnghttp2-14 amd64 1.43.0-1+deb11u2 [77.0 kB]
# [+] Building 5.5s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   4.9s
#  => => # Get:11 http://deb.debian.org/debian-security bullseye-security/main am
#  => => # d64 libcurl4 amd64 7.74.0-1.3+deb11u15 [347 kB]
#  => => # Get:12 http://deb.debian.org/debian-security bullseye-security/main am
#  => => # d64 curl amd64 7.74.0-1.3+deb11u15 [272 kB]
#  => => # Get:13 http://deb.debian.org/debian bullseye/main amd64 libldap-common
#  => => #  all 2.4.57+dfsg-3+deb11u1 [95.8 kB]
# [+] Building 5.7s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   5.0s
#  => => # Get:13 http://deb.debian.org/debian bullseye/main amd64 libldap-common
#  => => #  all 2.4.57+dfsg-3+deb11u1 [95.8 kB]
#  => => # Get:14 http://deb.debian.org/debian bullseye/main amd64 libsasl2-modul
#  => => # es amd64 2.1.27+dfsg-2.1+deb11u1 [104 kB]
#  => => # Get:15 http://deb.debian.org/debian bullseye/main amd64 publicsuffix a
#  => => # ll 20220811.1734-0+deb11u1 [127 kB]
# [+] Building 5.7s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   5.0s
#  => => # Get:14 http://deb.debian.org/debian bullseye/main amd64 libsasl2-modul
#  => => # es amd64 2.1.27+dfsg-2.1+deb11u1 [104 kB]
#  => => # Get:15 http://deb.debian.org/debian bullseye/main amd64 publicsuffix a
#  => => # ll 20220811.1734-0+deb11u1 [127 kB]
#  => => # debconf: delaying package configuration, since apt-utils is not instal
#  => => # led
# [+] Building 5.9s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   5.3s
#  => => # led
#  => => # Fetched 3000 kB in 1s (4926 kB/s)
#  => => # Selecting previously unselected package openssl.
#  => => # (Reading database ... 6673 files and directories currently installed.)
#  => => # Preparing to unpack .../00-openssl_1.1.1w-0+deb11u3_amd64.deb ...
#  => => # Unpacking openssl (1.1.1w-0+deb11u3) ...
# [+] Building 6.0s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get   5.4s
#  => => # Fetched 3000 kB in 1s (4926 kB/s)
#  => => # Selecting previously unselected package openssl.
#  => => # (Reading database ... 6673 files and directories currently installed.)
#  => => # Preparing to unpack .../00-openssl_1.1.1w-0+deb11u3_amd64.deb ...
#  => => # Unpacking openssl (1.1.1w-0+deb11u3) ...
#  => => # Selecting previously unselected package ca-certificates.
# [+] Building 6.2s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
# ...
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        1.7s
# [+] Building 30.4s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get  10.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  5.9s
#  => exporting to image                                                    12.9s
#  => => exporting layers                                                   10.9s
#  => => exporting manifest sha256:4ccfb5f5f4a9293d14d0f8636ff4e47ddaab4c14  0.0s
#  => => exporting config sha256:b3fc36fb7c99f425b23c1d21723c54f447365bd099  0.0s
#  => => exporting attestation manifest sha256:eeeb635b237618efdfea64d3aec2  0.1s
#  => => exporting manifest list sha256:77cb187cdb1cbac7e4b261319f684eb8c67  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        1.8s
# [+] Building 30.5s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get  10.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  5.9s
#  => exporting to image                                                    13.1s
#  => => exporting layers                                                   10.9s
#  => => exporting manifest sha256:4ccfb5f5f4a9293d14d0f8636ff4e47ddaab4c14  0.0s
#  => => exporting config sha256:b3fc36fb7c99f425b23c1d21723c54f447365bd099  0.0s
#  => => exporting attestation manifest sha256:eeeb635b237618efdfea64d3aec2  0.1s
#  => => exporting manifest list sha256:77cb187cdb1cbac7e4b261319f684eb8c67  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        1.9s
# [+] Building 30.7s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get  10.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  5.9s
#  => exporting to image                                                    13.2s
#  => => exporting layers                                                   10.9s
#  => => exporting manifest sha256:4ccfb5f5f4a9293d14d0f8636ff4e47ddaab4c14  0.0s
#  => => exporting config sha256:b3fc36fb7c99f425b23c1d21723c54f447365bd099  0.0s
#  => => exporting attestation manifest sha256:eeeb635b237618efdfea64d3aec2  0.1s
#  => => exporting manifest list sha256:77cb187cdb1cbac7e4b261319f684eb8c67  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        2.1s
# [+] Building 30.8s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get  10.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  5.9s
#  => exporting to image                                                    13.4s
#  => => exporting layers                                                   10.9s
#  => => exporting manifest sha256:4ccfb5f5f4a9293d14d0f8636ff4e47ddaab4c14  0.0s
#  => => exporting config sha256:b3fc36fb7c99f425b23c1d21723c54f447365bd099  0.0s
#  => => exporting attestation manifest sha256:eeeb635b237618efdfea64d3aec2  0.1s
#  => => exporting manifest list sha256:77cb187cdb1cbac7e4b261319f684eb8c67  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        2.3s
# [+] Building 31.0s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get  10.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  5.9s
#  => exporting to image                                                    13.5s
#  => => exporting layers                                                   10.9s
#  => => exporting manifest sha256:4ccfb5f5f4a9293d14d0f8636ff4e47ddaab4c14  0.0s
#  => => exporting config sha256:b3fc36fb7c99f425b23c1d21723c54f447365bd099  0.0s
#  => => exporting attestation manifest sha256:eeeb635b237618efdfea64d3aec2  0.1s
#  => => exporting manifest list sha256:77cb187cdb1cbac7e4b261319f684eb8c67  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        2.4s
# [+] Building 31.1s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get  10.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  5.9s
#  => exporting to image                                                    13.7s
#  => => exporting layers                                                   10.9s
#  => => exporting manifest sha256:4ccfb5f5f4a9293d14d0f8636ff4e47ddaab4c14  0.0s
#  => => exporting config sha256:b3fc36fb7c99f425b23c1d21723c54f447365bd099  0.0s
#  => => exporting attestation manifest sha256:eeeb635b237618efdfea64d3aec2  0.1s
#  => => exporting manifest list sha256:77cb187cdb1cbac7e4b261319f684eb8c67  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        2.6s
# [+] Building 31.3s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get  10.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  5.9s
#  => exporting to image                                                    13.8s
#  => => exporting layers                                                   10.9s
#  => => exporting manifest sha256:4ccfb5f5f4a9293d14d0f8636ff4e47ddaab4c14  0.0s
#  => => exporting config sha256:b3fc36fb7c99f425b23c1d21723c54f447365bd099  0.0s
#  => => exporting attestation manifest sha256:eeeb635b237618efdfea64d3aec2  0.1s
#  => => exporting manifest list sha256:77cb187cdb1cbac7e4b261319f684eb8c67  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        2.7s
# [+] Building 31.4s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get  10.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  5.9s
#  => exporting to image                                                    14.0s
#  => => exporting layers                                                   10.9s
#  => => exporting manifest sha256:4ccfb5f5f4a9293d14d0f8636ff4e47ddaab4c14  0.0s
#  => => exporting config sha256:b3fc36fb7c99f425b23c1d21723c54f447365bd099  0.0s
#  => => exporting attestation manifest sha256:eeeb635b237618efdfea64d3aec2  0.1s
#  => => exporting manifest list sha256:77cb187cdb1cbac7e4b261319f684eb8c67  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        2.9s
# [+] Building 31.6s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get  10.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  5.9s
#  => exporting to image                                                    14.1s
#  => => exporting layers                                                   10.9s
#  => => exporting manifest sha256:4ccfb5f5f4a9293d14d0f8636ff4e47ddaab4c14  0.0s
#  => => exporting config sha256:b3fc36fb7c99f425b23c1d21723c54f447365bd099  0.0s
#  => => exporting attestation manifest sha256:eeeb635b237618efdfea64d3aec2  0.1s
#  => => exporting manifest list sha256:77cb187cdb1cbac7e4b261319f684eb8c67  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        3.0s
# [+] Building 31.8s (7/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get  10.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  5.9s
#  => exporting to image                                                    14.2s
#  => => exporting layers                                                   10.9s
#  => => exporting manifest sha256:4ccfb5f5f4a9293d14d0f8636ff4e47ddaab4c14  0.0s
#  => => exporting config sha256:b3fc36fb7c99f425b23c1d21723c54f447365bd099  0.0s
#  => => exporting attestation manifest sha256:eeeb635b237618efdfea64d3aec2  0.1s
#  => => exporting manifest list sha256:77cb187cdb1cbac7e4b261319f684eb8c67  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        3.0s
# [+] Building 31.9s (7/7) FINISHED                                docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 508B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/3] RUN apt-get update  && apt-get install -y curl tar  && apt-get  10.9s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/down  5.9s
#  => exporting to image                                                    14.2s
#  => => exporting layers                                                   10.9s
#  => => exporting manifest sha256:4ccfb5f5f4a9293d14d0f8636ff4e47ddaab4c14  0.0s
#  => => exporting config sha256:b3fc36fb7c99f425b23c1d21723c54f447365bd099  0.0s
#  => => exporting attestation manifest sha256:eeeb635b237618efdfea64d3aec2  0.1s
#  => => exporting manifest list sha256:77cb187cdb1cbac7e4b261319f684eb8c67  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        3.0s

# %%
# run the docker image to give out the version of salmon
# !docker run salmon salmon
# Out:
# salmon v1.5.2
#
# Usage:  salmon -h|--help or
#         salmon -v|--version or
#         salmon -c|--cite or
#         salmon [--no-version-check] <COMMAND> [-h | options]
#
# Commands:
#      index      : create a salmon index
#      quant      : quantify a sample
#      alevin     : single cell analysis
#      swim       : perform super-secret operation
#      quantmerge : merge multiple quantifications into a single file

# %% [markdown]
# ## Do you think bioinformaticians have to create a docker image every time they want to run a tool?
#
# Find the salmon docker image online and run it on your computer.
#
# What is https://biocontainers.pro/ ?

# %%
# !docker pull combinelab/salmon:latest
# Out:
# latest: Pulling from combinelab/salmon
#
# 9485d7ab: Pulling fs layer
# 7f213c76: Pulling fs layer
# 0bdd40c3: Pulling fs layer
# 1ed9ab84: Pulling fs layer
# Digest: sha256:cefd8bb0b2ed9b07f22b5f0fc317ddda540e5b0dc00810d1ff0d92fee5d80370[4A
# Status: Downloaded newer image for combinelab/salmon:latest
# docker.io/combinelab/salmon:latest

# %%
# !docker run combinelab/salmon salmon
# Out:
# salmon v1.10.3
#
# Usage:  salmon -h|--help or
#         salmon -v|--version or
#         salmon -c|--cite or
#         salmon [--no-version-check] <COMMAND> [-h | options]
#
# Commands:
#      index      : create a salmon index
#      quant      : quantify a sample
#      alevin     : single cell analysis
#      swim       : perform super-secret operation
#      quantmerge : merge multiple quantifications into a single file

# %%
# I also foudn the salmon docker image here:
# !docker pull quay.io/biocontainers/salmon:1.10.3--h45fbf2d_5
# Out:
# 1.10.3--h45fbf2d_5: Pulling from biocontainers/salmon
#
# Digest: sha256:3938cc6dfaca6f7ee14eac0cdc0f305fdff8faa7f14541c72e684feb1b443a741A
# Status: Downloaded newer image for quay.io/biocontainers/salmon:1.10.3--h45fbf2d_5
# quay.io/biocontainers/salmon:1.10.3--h45fbf2d_5

# %% [markdown]
# Biocontainer is a community-driven project that provides the infrastructure and basic guidelines to create, manage and distribute bioinformatics containers with special focus in proteomics, genomics, transcriptomics and metabolomics. BioContainers is based on Docker. [1] On the website there is a registry which holds a list fo all biocontainers and workflows, including metadata and statistics. They show specifications, and architecture to create, deploy and maintain software containers using Conda and Docker technologies. [2]
#
# 1) https://cyverse-foundational-open-science-skills-2019.readthedocs-hosted.com/en/latest/Containers/biocontainers.html
# 2) https://biocontainers.pro/

# %% [markdown]
# ## Are there other ways to create Docker (or Apptainer) images?
#
# What is https://seqera.io/containers/ ?
#
# Through this website I can select different packages and add them together and then select a link via "get container" which I can use like we did it with the fastqc.
